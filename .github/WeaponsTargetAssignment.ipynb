# %%
import numpy as np
import cvxpy as cvx
import pandas as pd
from IPython.display import display #pretty print

# %%
#kill probabilities
p = np.array([[.8, .7, .7, .95, .8],
              [.8, .7, .7, .95, .8],
              [.95, .8, .8, .95, .9],
              [.5, .6, .6, .9, .7],
              [.5, .6, .6, .9, .7]])

#target values
v = np.array([5., 6., 10., 8., 8])

targets = ['I1', 'I2', 'R1', 'S1', 'S2']
weapons = ['A1', 'M1', 'M2', 'SA', 'DA']

p_df = pd.DataFrame(p, columns=weapons, index=targets) #formatting like this makes print prettier
display(p_df)
# Out:
#       A1   M1   M2    SA   DA
# I1  0.80  0.7  0.7  0.95  0.8
# I2  0.80  0.7  0.7  0.95  0.8
# R1  0.95  0.8  0.8  0.95  0.9
# S1  0.50  0.6  0.6  0.90  0.7
# S2  0.50  0.6  0.6  0.90  0.7

# %%
#in class: model this weapons target assignment problem in cvxpy
