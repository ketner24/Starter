# %%
import numpy as np
import cvxpy as cvx
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
n = 20
np.random.seed(0)
X = np.random.uniform(low=-1., high=1., size=(n,2))

# %%
plt.plot(X[:,0], X[:,1], '^', label='Units')
plt.xlabel('x coordinate')
plt.ylabel('y coordinate')
plt.legend()
plt.show()

# %%
#In-class task. Place a resupply vessel in an optimal position to resupply these units.
#Plot it as a red circle.
#find an optimal position with and without the constraint "the vessel should be outside the WEZ",
#where you formulate this constraint as you think most appropriate.
#Hint: Consider the atomic functions here https://www.cvxpy.org/tutorial/functions/index.html#
